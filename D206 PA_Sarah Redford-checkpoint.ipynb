# %%
# Import packages
import pandas as pd
from pandas import DataFrame
import numpy as np
import missingno as msno
# Import SciPy to use in calculation the z-score and other normalizations
import scipy.stats as stats
# Import Matplotlib and seaborn to help visulalize data
import seaborn as sns
import matplotlib.pyplot as plt
#import package for completing PCA
from sklearn.decomposition import PCA

# Import data from CSV file
df = pd.read_csv('churn_raw_data.csv',dtype={'C:/Users/sered/OneDrive/Desktop/WGU Masters Degree/D206/churn_raw_data.csv':np.int64})
df.head(5)
# Out:
#    Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 0           1          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 1           2          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 2           3          3     K191035  344d114c-3736-4be5-98f7-c72c281e2d35
# 3           4          4      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311
# 4           5          5     K662701  68a861fd-0d20-4e51-a587-8a90407ee574
#
#           City State                 County    Zip       Lat        Lng  ...  \
# 0  Point Baker    AK  Prince of Wales-Hyder  99927  56.25100 -133.37571  ...
# 1  West Branch    MI                 Ogemaw  48661  44.32893  -84.24080  ...
# 2      Yamhill    OR                Yamhill  97148  45.35589 -123.24657  ...
# 3      Del Mar    CA              San Diego  92014  32.96687 -117.24798  ...
# 4    Needville    TX              Fort Bend  77461  29.38012  -95.80673  ...
#
# ...

# %%
# Data Profiling - Run this to get a look at how python views the data set information.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10000 non-null  int64
#  1   CaseOrder             10000 non-null  int64
#  2   Customer_id           10000 non-null  object
#  3   Interaction           10000 non-null  object
#  4   City                  10000 non-null  object
#  5   State                 10000 non-null  object
#  6   County                10000 non-null  object
#  7   Zip                   10000 non-null  int64
#  8   Lat                   10000 non-null  float64
#  9   Lng                   10000 non-null  float64
#  10  Population            10000 non-null  int64
#  11  Area                  10000 non-null  object
#  12  Timezone              10000 non-null  object
#  13  Job                   10000 non-null  object
#  14  Children              7505 non-null   float64
# ...

# %%
# Use duplicate method to show what rows are duplicates
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
# Count the number of data duplicates in the dataset
print(df.duplicated().value_counts())
# Out:
# False    10000
# Name: count, dtype: int64

# %%
# Find the number of null values in each column of the dataset to better understand which columns have incomplete data
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# CaseOrder                  0
# Customer_id                0
# Interaction                0
# City                       0
# State                      0
# County                     0
# Zip                        0
# Lat                        0
# Lng                        0
# Population                 0
# Area                       0
# Timezone                   0
# Job                        0
# Children                2495
# Age                     2475
# Education                  0
# Employment                 0
# Income                  2490
# Marital                    0
# Gender                     0
# Churn                      0
# Outage_sec_perweek         0
# Email                      0
# Contacts                   0
# Yearly_equip_failure       0
# Techie                  2477
# Contract                   0
# Port_modem                 0
# Tablet                     0
# InternetService         2129
# Phone                   1026
# ...

# %%
# Install missingno to create visualizations later in the data cleaning process
# !pip install missingno

# %%
# Create a visualization to more easily view the null values
msno.matrix(df, fontsize=12, labels=True)
plt.title('Null Values Matrix')
plt.show()

# %%
# Create histogram for children column to examine distribution
plt.hist(df['Children'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Fill in null values for the Children column using median because of the skewed distribution
df['Children'].fillna(df['Children'].median(), inplace=True)

# %%
# Verify imputation - Children column should no longer contain null values
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# CaseOrder                  0
# Customer_id                0
# Interaction                0
# City                       0
# State                      0
# County                     0
# Zip                        0
# Lat                        0
# Lng                        0
# Population                 0
# Area                       0
# Timezone                   0
# Job                        0
# Children                   0
# Age                     2475
# Education                  0
# Employment                 0
# Income                  2490
# Marital                    0
# Gender                     0
# Churn                      0
# Outage_sec_perweek         0
# Email                      0
# Contacts                   0
# Yearly_equip_failure       0
# Techie                  2477
# Contract                   0
# Port_modem                 0
# Tablet                     0
# InternetService         2129
# Phone                   1026
# ...

# %%
# Verify the distribution of the data after removing null values - distribution should not significantly change 
plt.hist(df['Children'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create histogram for Age column to examine distribution
plt.hist(df['Age'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Fill in null values for the Age column using mean because of the uniform distribution and round to remove any decimal points
df['Age'].fillna(df['Age'].mean().round(), inplace=True)

# %%
# Verify imputation - Children column should no longer contain null values
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# CaseOrder                  0
# Customer_id                0
# Interaction                0
# City                       0
# State                      0
# County                     0
# Zip                        0
# Lat                        0
# Lng                        0
# Population                 0
# Area                       0
# Timezone                   0
# Job                        0
# Children                   0
# Age                        0
# Education                  0
# Employment                 0
# Income                  2490
# Marital                    0
# Gender                     0
# Churn                      0
# Outage_sec_perweek         0
# Email                      0
# Contacts                   0
# Yearly_equip_failure       0
# Techie                  2477
# Contract                   0
# Port_modem                 0
# Tablet                     0
# InternetService         2129
# Phone                   1026
# ...

# %%
# Verify the distribution of the data after removing null values - distribution should not significantly change 
plt.hist(df['Age'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create histogram for Income column to examine distribution
plt.hist(df['Income'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Fill in null values for the Income column using median because of the skewed distribution
df['Income'].fillna(df['Income'].median(), inplace=True)

# %%
# Verify imputation - Income column should no longer contain null values
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# CaseOrder                  0
# Customer_id                0
# Interaction                0
# City                       0
# State                      0
# County                     0
# Zip                        0
# Lat                        0
# Lng                        0
# Population                 0
# Area                       0
# Timezone                   0
# Job                        0
# Children                   0
# Age                        0
# Education                  0
# Employment                 0
# Income                     0
# Marital                    0
# Gender                     0
# Churn                      0
# Outage_sec_perweek         0
# Email                      0
# Contacts                   0
# Yearly_equip_failure       0
# Techie                  2477
# Contract                   0
# Port_modem                 0
# Tablet                     0
# InternetService         2129
# Phone                   1026
# ...

# %%
# Verify the distribution of the data after removing null values - distribution should not significantly change 
plt.hist(df['Income'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create a visualization for the Techie column to examine distribution
df['Techie'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Techie'>

# %%
# Fill in null values for the Techie column using mode because of the categorical variables
df['Techie']=df['Techie'].fillna(df['Techie'].mode()[0])

# %%
# Verify imputation - Techie column should no longer contain null values
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# CaseOrder                  0
# Customer_id                0
# Interaction                0
# City                       0
# State                      0
# County                     0
# Zip                        0
# Lat                        0
# Lng                        0
# Population                 0
# Area                       0
# Timezone                   0
# Job                        0
# Children                   0
# Age                        0
# Education                  0
# Employment                 0
# Income                     0
# Marital                    0
# Gender                     0
# Churn                      0
# Outage_sec_perweek         0
# Email                      0
# Contacts                   0
# Yearly_equip_failure       0
# Techie                     0
# Contract                   0
# Port_modem                 0
# Tablet                     0
# InternetService         2129
# Phone                   1026
# ...

# %%
# Create a visualization for the Techie column to verify imputation
df['Techie'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Techie'>

# %%
# Create a visualization for the InternetService column to examine distribution
df['InternetService'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='InternetService'>

# %%
# Fill in null values for the InternetService column using mode because of the categorical variables
df['InternetService']=df['InternetService'].fillna(df['InternetService'].mode()[0])

# %%
# Verify imputation - InternetService column should no longer contain null values
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# CaseOrder                  0
# Customer_id                0
# Interaction                0
# City                       0
# State                      0
# County                     0
# Zip                        0
# Lat                        0
# Lng                        0
# Population                 0
# Area                       0
# Timezone                   0
# Job                        0
# Children                   0
# Age                        0
# Education                  0
# Employment                 0
# Income                     0
# Marital                    0
# Gender                     0
# Churn                      0
# Outage_sec_perweek         0
# Email                      0
# Contacts                   0
# Yearly_equip_failure       0
# Techie                     0
# Contract                   0
# Port_modem                 0
# Tablet                     0
# InternetService            0
# Phone                   1026
# ...

# %%
# Create a visualization for the InternetService column to verify imputation
df['InternetService'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='InternetService'>

# %%
# Create a visualization for the Phone column to examine distribution
df['Phone'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Phone'>

# %%
# Fill in null values for the Phone column using mode because of the categorical variables
df['Phone']=df['Phone'].fillna(df['Phone'].mode()[0])

# %%
# Verify imputation - Phone column should no longer contain null values
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# CaseOrder                  0
# Customer_id                0
# Interaction                0
# City                       0
# State                      0
# County                     0
# Zip                        0
# Lat                        0
# Lng                        0
# Population                 0
# Area                       0
# Timezone                   0
# Job                        0
# Children                   0
# Age                        0
# Education                  0
# Employment                 0
# Income                     0
# Marital                    0
# Gender                     0
# Churn                      0
# Outage_sec_perweek         0
# Email                      0
# Contacts                   0
# Yearly_equip_failure       0
# Techie                     0
# Contract                   0
# Port_modem                 0
# Tablet                     0
# InternetService            0
# Phone                      0
# ...

# %%
# Create a visualization for the Phone column to verify imputation
df['Phone'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Phone'>

# %%
# Create a visualization for the TechSupport column to examine distribution
df['TechSupport'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TechSupport'>

# %%
# Fill in null values for the TechSupport column using mode because of the categorical variables
df['TechSupport']=df['TechSupport'].fillna(df['TechSupport'].mode()[0])

# %%
# Verify imputation - TechSupport column should no longer contain null values
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# CaseOrder                  0
# Customer_id                0
# Interaction                0
# City                       0
# State                      0
# County                     0
# Zip                        0
# Lat                        0
# Lng                        0
# Population                 0
# Area                       0
# Timezone                   0
# Job                        0
# Children                   0
# Age                        0
# Education                  0
# Employment                 0
# Income                     0
# Marital                    0
# Gender                     0
# Churn                      0
# Outage_sec_perweek         0
# Email                      0
# Contacts                   0
# Yearly_equip_failure       0
# Techie                     0
# Contract                   0
# Port_modem                 0
# Tablet                     0
# InternetService            0
# Phone                      0
# ...

# %%
# Create a visualization for the TechSupport column to verify imputation
df['TechSupport'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TechSupport'>

# %%
# Create histogram for Tenure column to examine distribution
plt.hist(df['Tenure'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Fill in null values for the Tenure column using median because of the bi-modal distribution
df['Tenure'].fillna(df['Tenure'].median(), inplace=True)

# %%
# Verify imputation - Tenure column should no longer contain null values
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# CaseOrder                  0
# Customer_id                0
# Interaction                0
# City                       0
# State                      0
# County                     0
# Zip                        0
# Lat                        0
# Lng                        0
# Population                 0
# Area                       0
# Timezone                   0
# Job                        0
# Children                   0
# Age                        0
# Education                  0
# Employment                 0
# Income                     0
# Marital                    0
# Gender                     0
# Churn                      0
# Outage_sec_perweek         0
# Email                      0
# Contacts                   0
# Yearly_equip_failure       0
# Techie                     0
# Contract                   0
# Port_modem                 0
# Tablet                     0
# InternetService            0
# Phone                      0
# ...

# %%
# Verify the distribution of the data after removing null values - distribution should not significantly change 
plt.hist(df['Tenure'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create histogram for Bandwidth_GB_Year column to examine distribution
plt.hist(df['Bandwidth_GB_Year'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Fill in null values for the Bandwidth_GB_Year column using median because of the bi-modal distribution
df['Bandwidth_GB_Year'].fillna(df['Bandwidth_GB_Year'].median(), inplace=True)

# %%
# Verify imputation - Bandwidth_GB_Year column should no longer contain null values
df.isnull().sum()
# Out:
# Unnamed: 0              0
# CaseOrder               0
# Customer_id             0
# Interaction             0
# City                    0
# State                   0
# County                  0
# Zip                     0
# Lat                     0
# Lng                     0
# Population              0
# Area                    0
# Timezone                0
# Job                     0
# Children                0
# Age                     0
# Education               0
# Employment              0
# Income                  0
# Marital                 0
# Gender                  0
# Churn                   0
# Outage_sec_perweek      0
# Email                   0
# Contacts                0
# Yearly_equip_failure    0
# Techie                  0
# Contract                0
# Port_modem              0
# Tablet                  0
# InternetService         0
# Phone                   0
# Multiple                0
# OnlineSecurity          0
# OnlineBackup            0
# ...

# %%
# Verify the distribution of the data after removing null values - distribution should not significantly change 
plt.hist(df['Bandwidth_GB_Year'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create a visualization to more easily view the null values and verify that there are no null values after imputation
msno.matrix(df, fontsize=12, labels=True)
plt.title('Null Values Matrix')
plt.show()

# %%
# Use z-score to detect any outliers in the Yearly Equipment Failure column
df['Zscore_Failure']=stats.zscore(df['Yearly_equip_failure'])
df[['Yearly_equip_failure','Zscore_Failure']].head
# Out:
# <bound method NDFrame.head of       Yearly_equip_failure  Zscore_Failure
# 0                        1        0.946658
# 1                        1        0.946658
# 2                        1        0.946658
# 3                        0       -0.625864
# 4                        1        0.946658
# ...                    ...             ...
# 9995                     0       -0.625864
# 9996                     0       -0.625864
# 9997                     0       -0.625864
# 9998                     0       -0.625864
# 9999                     0       -0.625864
#
# [10000 rows x 2 columns]>

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['Yearly_equip_failure'].plot(kind='box', title='Yearly Failures')
plt.show()

# %%
# histogram to view outliers
plt.hist(df['Yearly_equip_failure'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Determine the count of outliers in the equipment failure column that are greater than 2
Failure_query = df.query('Yearly_equip_failure > 2')
Failure_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94 entries, 8 to 9967
# Data columns (total 53 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            94 non-null     int64
#  1   CaseOrder             94 non-null     int64
#  2   Customer_id           94 non-null     object
#  3   Interaction           94 non-null     object
#  4   City                  94 non-null     object
#  5   State                 94 non-null     object
#  6   County                94 non-null     object
#  7   Zip                   94 non-null     int64
#  8   Lat                   94 non-null     float64
#  9   Lng                   94 non-null     float64
#  10  Population            94 non-null     int64
#  11  Area                  94 non-null     object
#  12  Timezone              94 non-null     object
#  13  Job                   94 non-null     object
#  14  Children              94 non-null     float64
# ...

# %%
# impute the median for outliers in the yearly failures column that are larger than 3. There are only 8 entries larger than 3, so I want to change
# those to the median so that those few don't throw off the analysis for the rest
df['Yearly_equip_failure'] = np.where(df['Yearly_equip_failure'] > 2, np.nan, df['Yearly_equip_failure'])

# %%
df['Yearly_equip_failure'].fillna(df['Yearly_equip_failure'].median(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 53 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10000 non-null  int64
#  1   CaseOrder             10000 non-null  int64
#  2   Customer_id           10000 non-null  object
#  3   Interaction           10000 non-null  object
#  4   City                  10000 non-null  object
#  5   State                 10000 non-null  object
#  6   County                10000 non-null  object
#  7   Zip                   10000 non-null  int64
#  8   Lat                   10000 non-null  float64
#  9   Lng                   10000 non-null  float64
#  10  Population            10000 non-null  int64
#  11  Area                  10000 non-null  object
#  12  Timezone              10000 non-null  object
#  13  Job                   10000 non-null  object
#  14  Children              10000 non-null  float64
# ...

# %%
# Verify that the outliers have been removed from the column
df['Yearly_equip_failure'].plot(kind='box', title='Yearly Failures')
plt.show()

# %%
# Use z-score to detect any outliers in the MonthlyCharge column
df['Zscore_MonthlyCharge']=stats.zscore(df['MonthlyCharge'])
df[['MonthlyCharge','Zscore_MonthlyCharge']].head
# Out:
# <bound method NDFrame.head of       MonthlyCharge  Zscore_MonthlyCharge
# 0        171.449762             -0.060613
# 1        242.948015              1.589348
# 2        159.440398             -0.337752
# 3        120.249493             -1.242158
# 4        150.761216             -0.538041
# ...             ...                   ...
# 9995     159.828800             -0.328789
# 9996     208.856400              0.802618
# 9997     168.220900             -0.135125
# 9998     252.628600              1.812746
# 9999     218.371000              1.022186
#
# [10000 rows x 2 columns]>

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['MonthlyCharge'].plot(kind='box', title='Clients Monthly Charge')
plt.show()

# %%
# Determine the count of outliers in the monthly charge column that are greater than 300 to better understand outliers
MonthlyCharge_query = df.query('MonthlyCharge > 295')
MonthlyCharge_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 798 to 8755
# Data columns (total 54 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            7 non-null      int64
#  1   CaseOrder             7 non-null      int64
#  2   Customer_id           7 non-null      object
#  3   Interaction           7 non-null      object
#  4   City                  7 non-null      object
#  5   State                 7 non-null      object
#  6   County                7 non-null      object
#  7   Zip                   7 non-null      int64
#  8   Lat                   7 non-null      float64
#  9   Lng                   7 non-null      float64
#  10  Population            7 non-null      int64
#  11  Area                  7 non-null      object
#  12  Timezone              7 non-null      object
#  13  Job                   7 non-null      object
#  14  Children              7 non-null      float64
# ...

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['Income'].plot(kind='box', title='Clients Income')
plt.show()

# %%
# Determine the count of outliers in the income column that are greater than $100,000 to better understand outliers
Income_query = df.query('Income > 200000')
Income_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 4249 to 9180
# Data columns (total 54 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            3 non-null      int64
#  1   CaseOrder             3 non-null      int64
#  2   Customer_id           3 non-null      object
#  3   Interaction           3 non-null      object
#  4   City                  3 non-null      object
#  5   State                 3 non-null      object
#  6   County                3 non-null      object
#  7   Zip                   3 non-null      int64
#  8   Lat                   3 non-null      float64
#  9   Lng                   3 non-null      float64
#  10  Population            3 non-null      int64
#  11  Area                  3 non-null      object
#  12  Timezone              3 non-null      object
#  13  Job                   3 non-null      object
#  14  Children              3 non-null      float64
# ...

# %%
# impute the median for outliers in the income column that are larger than $200,000 to remove significantly higher salaries from the dataset
# replace values with null values
df['Income'] = np.where(df['Income'] > 200000, np.nan, df['Income'])
# fill in the null values with the median of the column
df['Income'].fillna(df['Income'].median(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 54 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10000 non-null  int64
#  1   CaseOrder             10000 non-null  int64
#  2   Customer_id           10000 non-null  object
#  3   Interaction           10000 non-null  object
#  4   City                  10000 non-null  object
#  5   State                 10000 non-null  object
#  6   County                10000 non-null  object
#  7   Zip                   10000 non-null  int64
#  8   Lat                   10000 non-null  float64
#  9   Lng                   10000 non-null  float64
#  10  Population            10000 non-null  int64
#  11  Area                  10000 non-null  object
#  12  Timezone              10000 non-null  object
#  13  Job                   10000 non-null  object
#  14  Children              10000 non-null  float64
# ...

# %%
# Verify that the outliers have been removed and replaced with the median
df['Income'].plot(kind='box', title='Clients Income')
plt.show()

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['Outage_sec_perweek'].plot(kind='box', title='Seconds Per Week Where Internet is Out')
plt.show()

# %%
# Determine the count of outliers in the outage per week column that are less than 0 to better understand outliers and fix them because there shouldn't be negative numbers in the column
Outage_query = df.query('Outage_sec_perweek > 30')
Outage_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 28 to 9980
# Data columns (total 54 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            500 non-null    int64
#  1   CaseOrder             500 non-null    int64
#  2   Customer_id           500 non-null    object
#  3   Interaction           500 non-null    object
#  4   City                  500 non-null    object
#  5   State                 500 non-null    object
#  6   County                500 non-null    object
#  7   Zip                   500 non-null    int64
#  8   Lat                   500 non-null    float64
#  9   Lng                   500 non-null    float64
#  10  Population            500 non-null    int64
#  11  Area                  500 non-null    object
#  12  Timezone              500 non-null    object
#  13  Job                   500 non-null    object
#  14  Children              500 non-null    float64
# ...

# %%
# Determine the count of outliers in the outage per week column that are greater than 20 to better understand outliers
Outage_query = df.query('Outage_sec_perweek < 0')
Outage_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 1904 to 8194
# Data columns (total 54 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            11 non-null     int64
#  1   CaseOrder             11 non-null     int64
#  2   Customer_id           11 non-null     object
#  3   Interaction           11 non-null     object
#  4   City                  11 non-null     object
#  5   State                 11 non-null     object
#  6   County                11 non-null     object
#  7   Zip                   11 non-null     int64
#  8   Lat                   11 non-null     float64
#  9   Lng                   11 non-null     float64
#  10  Population            11 non-null     int64
#  11  Area                  11 non-null     object
#  12  Timezone              11 non-null     object
#  13  Job                   11 non-null     object
#  14  Children              11 non-null     float64
# ...

# %%
# impute the median for outliers in the outage column that are larger than 30 to remove outliers from the dataset
# replace values with null values
df['Outage_sec_perweek'] = np.where(df['Outage_sec_perweek'] > 30, np.nan, df['Outage_sec_perweek'])
# fill in the null values with the median of the column
df['Outage_sec_perweek'].fillna(df['Outage_sec_perweek'].median(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 54 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10000 non-null  int64
#  1   CaseOrder             10000 non-null  int64
#  2   Customer_id           10000 non-null  object
#  3   Interaction           10000 non-null  object
#  4   City                  10000 non-null  object
#  5   State                 10000 non-null  object
#  6   County                10000 non-null  object
#  7   Zip                   10000 non-null  int64
#  8   Lat                   10000 non-null  float64
#  9   Lng                   10000 non-null  float64
#  10  Population            10000 non-null  int64
#  11  Area                  10000 non-null  object
#  12  Timezone              10000 non-null  object
#  13  Job                   10000 non-null  object
#  14  Children              10000 non-null  float64
# ...

# %%
# Verify that the outliers > 30 have been imputed to the median
df['Outage_sec_perweek'].plot(kind='box', title='Seconds Per Week Where Internet is Out')
plt.show()

# %%
# impute the median for outliers in the outage column that are < 0 to remove negative outliers from the dataset 
# replace values with null values
df['Outage_sec_perweek'] = np.where(df['Outage_sec_perweek'] < 0, np.nan, df['Outage_sec_perweek'])
# fill in the null values with the median of the column
df['Outage_sec_perweek'].fillna(df['Outage_sec_perweek'].median(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 54 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10000 non-null  int64
#  1   CaseOrder             10000 non-null  int64
#  2   Customer_id           10000 non-null  object
#  3   Interaction           10000 non-null  object
#  4   City                  10000 non-null  object
#  5   State                 10000 non-null  object
#  6   County                10000 non-null  object
#  7   Zip                   10000 non-null  int64
#  8   Lat                   10000 non-null  float64
#  9   Lng                   10000 non-null  float64
#  10  Population            10000 non-null  int64
#  11  Area                  10000 non-null  object
#  12  Timezone              10000 non-null  object
#  13  Job                   10000 non-null  object
#  14  Children              10000 non-null  float64
# ...

# %%
# Verify that the outliers < 0 have been imputed to the median and that no negative numbers remain
df['Outage_sec_perweek'].plot(kind='box', title='Seconds Per Week Where Internet is Out')
plt.show()

# %%
# Verify that there are no negative numbers in column
Outage_query = df.query('Outage_sec_perweek < 0')
Outage_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 54 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            0 non-null      int64
#  1   CaseOrder             0 non-null      int64
#  2   Customer_id           0 non-null      object
#  3   Interaction           0 non-null      object
#  4   City                  0 non-null      object
#  5   State                 0 non-null      object
#  6   County                0 non-null      object
#  7   Zip                   0 non-null      int64
#  8   Lat                   0 non-null      float64
#  9   Lng                   0 non-null      float64
#  10  Population            0 non-null      int64
#  11  Area                  0 non-null      object
#  12  Timezone              0 non-null      object
#  13  Job                   0 non-null      object
#  14  Children              0 non-null      float64
# ...

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['Tenure'].plot(kind='box', title='Months of Customer Tenure')
plt.show()

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['Bandwidth_GB_Year'].plot(kind='box', title='GB Used by Customer This Year')
plt.show()

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['Population'].plot(kind='box', title='Population of Clients')
plt.show()

# %%
# Determine the count of outliers in the population column that are greater than 20 to better understand outliers
Population_query = df.query('Population > 100000')
Population_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 6288 to 8320
# Data columns (total 54 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            3 non-null      int64
#  1   CaseOrder             3 non-null      int64
#  2   Customer_id           3 non-null      object
#  3   Interaction           3 non-null      object
#  4   City                  3 non-null      object
#  5   State                 3 non-null      object
#  6   County                3 non-null      object
#  7   Zip                   3 non-null      int64
#  8   Lat                   3 non-null      float64
#  9   Lng                   3 non-null      float64
#  10  Population            3 non-null      int64
#  11  Area                  3 non-null      object
#  12  Timezone              3 non-null      object
#  13  Job                   3 non-null      object
#  14  Children              3 non-null      float64
# ...

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['item1'].plot(kind='box', title='Survey - Timely Response')
plt.show()

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['item2'].plot(kind='box', title='Survey - Timely Fixes')
plt.show()

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['item3'].plot(kind='box', title='Survey - Timely Replacements')
plt.show()

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['item4'].plot(kind='box', title='Survey - Reliability')
plt.show()

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['item5'].plot(kind='box', title='Survey - Options')
plt.show()

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['item6'].plot(kind='box', title='Survey - Respectful Response')
plt.show()

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['item7'].plot(kind='box', title='Survey - Courteous Exchange')
plt.show()

# %%
# Create a box chart to visualize the data and help us see any outliers that may need to be fixed
df['item8'].plot(kind='box', title='Survey - Evidence of Active Listening')
plt.show()

# %%
# Create new dataframe to hold all continuous variables to be used for PCA
pca_df = df[['Income','Outage_sec_perweek','Tenure','MonthlyCharge','Bandwidth_GB_Year']]

# %%
# Verify that new dataframe was created properly
pca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Income              10000 non-null  float64
#  1   Outage_sec_perweek  10000 non-null  float64
#  2   Tenure              10000 non-null  float64
#  3   MonthlyCharge       10000 non-null  float64
#  4   Bandwidth_GB_Year   10000 non-null  float64
# dtypes: float64(5)
# memory usage: 390.8 KB

# %%
# Create a new datafram containing the normalized data from the pca dataset
pca_df_normalized = (pca_df-pca_df.mean())/pca_df.std()

# %%
# Verify that the new datafram was created properly
pca_df_normalized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Income              10000 non-null  float64
#  1   Outage_sec_perweek  10000 non-null  float64
#  2   Tenure              10000 non-null  float64
#  3   MonthlyCharge       10000 non-null  float64
#  4   Bandwidth_GB_Year   10000 non-null  float64
# dtypes: float64(5)
# memory usage: 390.8 KB

# %%
# Create pca dataframe and fit that dataframe into the normalized dataframe that was created before
pca = PCA(n_components=pca_df.shape[1])

# %%
pca.fit(pca_df_normalized)
# Out:
# PCA(n_components=5)

# %%
# Manually create the dataframe with the below column names for the principal components
final_pca = pd.DataFrame(pca.transform(pca_df_normalized),
                        columns=['PC1','PC2','PC3','PC4','PC5'])

# %%
# Verify the dataframe was created correctly
final_pca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PC1     10000 non-null  float64
#  1   PC2     10000 non-null  float64
#  2   PC3     10000 non-null  float64
#  3   PC4     10000 non-null  float64
#  4   PC5     10000 non-null  float64
# dtypes: float64(5)
# memory usage: 390.8 KB

# %%
# Display PCA Loadings
loadings = pd.DataFrame(pca.components_.T,
                        columns=['PC1','PC2','PC3','PC4','PC5'],
                        index=pca_df.columns)
loadings
# Out:
#                          PC1       PC2       PC3       PC4       PC5
# Income              0.004155 -0.285125  0.956327  0.064218  0.000661
# Outage_sec_perweek  0.014400  0.680495  0.154750  0.716019 -0.009435
# Tenure              0.705597 -0.053920 -0.020820  0.032258 -0.705515
# MonthlyCharge       0.042761  0.672847  0.247079 -0.694353 -0.047695
# Bandwidth_GB_Year   0.707163  0.000933 -0.002937 -0.005157  0.707025

# %%
# Create correlation matrix plot for loadings
matrix = sns.heatmap(loadings, annot=True, cmap='Spectral')
plt.show()

# %%
# Create scree plot to help determine which PC we should keep based on the eigenvalues
# calculate covariance and vectors before defining eigenvalues
cov_matrix = np.dot(pca_df_normalized.T, pca_df_normalized) / pca_df.shape[0]

# %%
eigenvalues = [np.dot(eigenvector.T, np.dot(cov_matrix, eigenvector)) for eigenvector in pca.components_]

# %%
# plot the eigenvalues in a scree plot 
plt.plot(eigenvalues)
plt.xlabel('Number of Components')
plt.ylabel('Eigenvalues')
plt.axhline(y=1, color="green")
plt.show()

# %%
df.to_csv('C:/Users/sered/OneDrive/Desktop/WGU Masters Degree/D206/D206_CleanedData 2.0.csv')
